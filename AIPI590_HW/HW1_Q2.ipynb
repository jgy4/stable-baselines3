# %%
# !apt-get install ffmpeg freeglut3-dev xvfb  # For visualization
# !pip install stable-baselines3[extra]

# %% [markdown]
# ## Installations & Imports

# %%
import stable_baselines3
stable_baselines3.__version__
# Out:
# '1.4.0'

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

#Imports
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.evaluation import evaluate_policy

# %%
#Create Callback Function

class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %% [markdown]
# ## Train & Monitor The Agent
# ## CartPole Game
# ## Evaluate Untrained Model

# %%
#Train & Monitor Agent 

import os
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make('CartPole-v1')
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Create action noise because TD3 and DDPG use a deterministic policy
#n_actions = env.action_space.shape[-1]
#action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model = A2C('MlpPolicy', env, verbose=0)

# We create a separate environment for evaluation
eval_env = gym.make('CartPole-v1')

# Evaluate the un-trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean_reward=41.30 +/- 20.50877860819605

# %%
# Train the agent
model.learn(total_timesteps=int(5e4), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 23.24
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2000
# Best mean reward: 23.24 - Last mean reward per episode: 27.30
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3000
# Best mean reward: 27.30 - Last mean reward per episode: 31.12
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4000
# Best mean reward: 31.12 - Last mean reward per episode: 38.47
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5000
# Best mean reward: 38.47 - Last mean reward per episode: 44.89
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6000
# Best mean reward: 44.89 - Last mean reward per episode: 51.11
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7000
# Best mean reward: 51.11 - Last mean reward per episode: 62.07
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8000
# Best mean reward: 62.07 - Last mean reward per episode: 68.24
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 9000
# Best mean reward: 68.24 - Last mean reward per episode: 77.46
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 10000
# Best mean reward: 77.46 - Last mean reward per episode: 88.28
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 11000
# Best mean reward: 88.28 - Last mean reward per episode: 97.40
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 12000
# Best mean reward: 97.40 - Last mean reward per episode: 105.40
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 13000
# Best mean reward: 105.40 - Last mean reward per episode: 117.68
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 14000
# Best mean reward: 117.68 - Last mean reward per episode: 124.93
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 15000
# Best mean reward: 124.93 - Last mean reward per episode: 131.69
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 16000
# Best mean reward: 131.69 - Last mean reward per episode: 140.55
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 17000
# Best mean reward: 140.55 - Last mean reward per episode: 151.72
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 18000
# Best mean reward: 151.72 - Last mean reward per episode: 161.31
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 19000
# Best mean reward: 161.31 - Last mean reward per episode: 170.26
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 20000
# Best mean reward: 170.26 - Last mean reward per episode: 178.88
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 21000
# Best mean reward: 178.88 - Last mean reward per episode: 188.28
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 22000
# Best mean reward: 188.28 - Last mean reward per episode: 195.29
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 23000
# Best mean reward: 195.29 - Last mean reward per episode: 204.96
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 24000
# Best mean reward: 204.96 - Last mean reward per episode: 214.31
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 25000
# Best mean reward: 214.31 - Last mean reward per episode: 223.66
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 26000
# Best mean reward: 223.66 - Last mean reward per episode: 232.97
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 27000
# Best mean reward: 232.97 - Last mean reward per episode: 244.85
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 28000
# Best mean reward: 244.85 - Last mean reward per episode: 254.21
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 29000
# Best mean reward: 254.21 - Last mean reward per episode: 263.46
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 30000
# Best mean reward: 263.46 - Last mean reward per episode: 272.33
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 31000
# Best mean reward: 272.33 - Last mean reward per episode: 281.51
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 32000
# Best mean reward: 281.51 - Last mean reward per episode: 289.91
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 33000
# Best mean reward: 289.91 - Last mean reward per episode: 298.14
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 34000
# Best mean reward: 298.14 - Last mean reward per episode: 303.17
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 35000
# Best mean reward: 303.17 - Last mean reward per episode: 310.38
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 36000
# Best mean reward: 310.38 - Last mean reward per episode: 319.60
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 37000
# Best mean reward: 319.60 - Last mean reward per episode: 329.32
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 38000
# Best mean reward: 329.32 - Last mean reward per episode: 337.00
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 39000
# Best mean reward: 337.00 - Last mean reward per episode: 343.43
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 40000
# Best mean reward: 343.43 - Last mean reward per episode: 352.55
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 41000
# Best mean reward: 352.55 - Last mean reward per episode: 362.58
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 42000
# Best mean reward: 362.58 - Last mean reward per episode: 369.31
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 43000
# Best mean reward: 369.31 - Last mean reward per episode: 377.91
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 44000
# Best mean reward: 377.91 - Last mean reward per episode: 386.24
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 45000
# Best mean reward: 386.24 - Last mean reward per episode: 395.72
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 46000
# Best mean reward: 395.72 - Last mean reward per episode: 403.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 47000
# Best mean reward: 403.52 - Last mean reward per episode: 411.71
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 48000
# Best mean reward: 411.71 - Last mean reward per episode: 419.71
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 49000
# Best mean reward: 419.71 - Last mean reward per episode: 426.95
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 50000
# Best mean reward: 426.95 - Last mean reward per episode: 431.52
# Saving new best model to /tmp/gym/best_model.zip

# %% [markdown]
# ## Visualize Training

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results([log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 LunarLander")

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), 'timesteps')
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y):]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title + " Smoothed")
    plt.show()

# %%
plot_results(log_dir)

# %% [markdown]
# ## Saving, Loading, and Evaluating The Agent

# %%
# Save the agent
model.save("a2c_CartPole")

#Save The Policy
policy = model.policy
policy.save("a2c_policy_CartPole.pkl")
  
# delete trained model to demonstrate loading
del model

# %%
#Load Agent
model = A2C.load("a2c_CartPole")

# %%
# We create a separate environment for evaluation
eval_env = gym.make('CartPole-v1')

# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean_reward=485.70 +/- 42.900000000000006

# %% [markdown]
# ## Final Evaluation Video

# %%
# Set up fake display; otherwise rendering will fail
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay

def show_videos(video_path='', prefix=''):
  """
  Taken from https://github.com/eleurent/highway-env

  :param video_path: (str) Path to the folder containing videos
  :param prefix: (str) Filter the video, showing only the only starting with this prefix
  """
  html = []
  for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
      video_b64 = base64.b64encode(mp4.read_bytes())
      html.append('''<video alt="{}" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>'''.format(mp4, video_b64.decode('ascii')))
  ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

def record_video(env_id, model, video_length=500, prefix='', video_folder='videos/'):
  """
  :param env_id: (str)
  :param model: (RL model)
  :param video_length: (int)
  :param prefix: (str)
  :param video_folder: (str)
  """
  eval_env = DummyVecEnv([lambda: gym.make('CartPole-v1')])
  # Start the video at step=0 and record 500 steps
  eval_env = VecVideoRecorder(eval_env, video_folder=video_folder,
                              record_video_trigger=lambda step: step == 0, video_length=video_length,
                              name_prefix=prefix)

  obs = eval_env.reset()
  for _ in range(video_length):
    action, _ = model.predict(obs)
    obs, _, _, _ = eval_env.step(action)

  # Close the video recorder
  eval_env.close()

# %%
record_video('CartPole-v1', model, video_length=500, prefix='a2c-CartPole')
# Out:
# Saving video to /content/videos/a2c-CartPole-step-0-to-step-500.mp4

# %%
show_videos('videos', prefix='a2c-CartPole')
# Out:
# <video alt="videos/a2c-CartPole-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
